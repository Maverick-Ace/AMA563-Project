# %% [markdown]
# ##### 用于快速查看mat数据

# %%
# 加载.mat数据
import scipy.io as sio
import numpy as np
import matplotlib.pyplot as plt

# %%
# 加载.mat文件
path = 'D:/BrainC/dataset/math_data/math_ant.mat'
data = sio.loadmat(path)

# %%
data.keys()
# Out:
# dict_keys(['__header__', '__version__', '__globals__', 'behav_math', 'cov_ID2', 'cov_gender', 'cov_grade'])

# %%
data[list(data.keys())[-1]].shape
# Out:
# (256, 1)

# %%
data[list(data.keys())[-1]]
# Out:
# array([[5],
#        [5],
#        [5],
#        [5],
#        [5],
#        [5],
#        [5],
#        [5],
#        [4],
#        [5],
#        [5],
#        [5],
#        [3],
#        [3],
#        [3],
#        [5],
#        [2],
#        [1],
#        [2],
#        [3],
#        [3],
#        [4],
#        [5],
#        [2],
#        [2],
#        [6],
#        [2],
#        [1],
#        [3],
#        [1],
#        [3],
#        [2],
#        [5],
#        [1],
#        [1],
#        [2],
#        [3],
#        [2],
#        [3],
#        [3],
#        [5],
#        [1],
#        [4],
#        [2],
#        [4],
#        [5],
#        [4],
#        [4],
#        [6],
#        [4],
#        [4],
#        [2],
#        [4],
#        [4],
#        [2],
#        [3],
#        [4],
#        [4],
#        [2],
#        [4],
#        [4],
#        [3],
#        [6],
#        [3],
#        [4],
#        [3],
#        [1],
#        [1],
#        [2],
#        [1],
#        [3],
# ...
